# %%
import requests
import pandas as pd
import time
import random

# %%
df = pd.read_csv('/Users/admlanno/Desktop/projects/EbitdaAnalysis/data/df_main.csv')

# %%
df.sample(5)
# Out:
#         № п/п                                 Наименование / ФИО  \
# 99777  405649  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СТРО...
# 82990  364941   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИБАС"
# 13774  163108   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АСАТА"
# 33302  219382  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДОМС...
# 84096  368201  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИМВОЛ"
#
#            Тип субъекта         Категория           ОГРН         ИНН  \
# 99777  Юридическое лицо  Микропредприятие  1192130001722  2130207828
# 82990  Юридическое лицо  Микропредприятие  1211600059660  1659217350
# 13774  Юридическое лицо  Микропредприятие  1207700388609  7720647901
# 33302  Юридическое лицо  Микропредприятие  1229100001173  9110029707
# 84096  Юридическое лицо  Микропредприятие  1227700477762  9709084222
#
#                         Основной вид деятельности  \
# 99777  41.20 Строительство жилых и нежилых зданий
# 82990  41.20 Строительство жилых и нежилых зданий
# 13774  41.20 Строительство жилых и нежилых зданий
# 33302  41.20 Строительство жилых и нежилых зданий
# 84096  41.20 Строительство жилых и нежилых зданий
#
#                                       Регион Район        Город  ...  \
# 99777    21 - Чувашская Республика - Чувашия   NaN  г Чебоксары  ...
# 82990  16 - Республика Татарстан (Татарстан)   NaN     г Казань  ...
# 13774                          77 - г.Москва   NaN          NaN  ...
# 33302                   91 - Республика Крым   NaN  г Евпатория  ...
# 84096                          77 - г.Москва   NaN          NaN  ...
#
#       Дата исключения из реестра Телефон E-mail  WWW Наличие лицензий  \
# 99777                        NaN     NaN    NaN  NaN               Да
# 82990                        NaN     NaN    NaN  NaN              Нет
# 13774                        NaN     NaN    NaN  NaN               Да
# 33302                        NaN     NaN    NaN  NaN              Нет
# 84096                        NaN     NaN    NaN  NaN              Нет
#
#       Наличие заключенных договоров, контрактов  \
# 99777                                       Нет
# 82990                                       Нет
# 13774                                       Нет
# 33302                                       Нет
# 84096                                       Нет
#
#       Производство инновационной, высокотехнологичной продукции  \
# 99777                                                Нет
# 82990                                                Нет
# 13774                                                Нет
# 33302                                                Нет
# 84096                                                Нет
#
#       Участие в программах партнерства Является социальным предприятием  \
# 99777                              Нет                              Нет
# 82990                              Нет                              Нет
# 13774                              Нет                              Нет
# 33302                              Нет                              Нет
# 84096                              Нет                              Нет
#
#       Среднесписочная численность работников за предшествующий календарный год
# 99777                                               12.0
# 82990                                                1.0
# 13774                                                1.0
# 33302                                                1.0
# 84096                                                1.0
#
# [5 rows x 23 columns]

# %%
def safe_convert(value):
    try:
        return float(value) if value is not None else 0
    except ValueError:
        return 0

def calculate_ebitda(inn):
    session = requests.Session()

    headers = {
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate, br, zstd",
        "Accept-Language": "en-GB,en;q=0.9",
        "Cache-Control": "no-cache",
        "Connection": "keep-alive",
        "Cookie": "disclaimed=true",
        "Host": "bo.nalog.ru",
        "Pragma": "no-cache",
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0",
        "sec-ch-ua": '"Not/A)Brand";v="8", "Chromium";v="126", "Microsoft Edge";v="126"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "Windows",
    }

    referers = [
        "https://bo.nalog.ru/",
        "https://bo.nalog.ru/otherpage",
        "https://bo.nalog.ru/anotherpage"
    ]


    headers["Referer"] = random.choice(referers)

    try:
        res = session.get(f"https://bo.nalog.ru/advanced-search/organizations/search?query={inn}&page=0", headers=headers).json()
    except requests.exceptions.JSONDecodeError:
        return None, "Ошибка декодирования JSON - сервер вернул невалидный ответ"
    except requests.exceptions.RequestException as e:
        return None, f"Ошибка запроса: {e}"

    if not res.get('content'):
        return None, "Организация не найдена"

    org_id = res['content'][0]['id']

    headers["Referer"] = random.choice(referers)

    try:
        financial_data = session.get(f"https://bo.nalog.ru/nbo/organizations/{org_id}/bfo", headers=headers).json()
    except requests.exceptions.JSONDecodeError:
        return None, "Ошибка декодирования JSON - сервер вернул невалидный ответ"
    except requests.exceptions.RequestException as e:
        return None, f"Ошибка запроса: {e}"

    ebitda_list = []

    for year_data in financial_data:
        financial_result = year_data.get('financialResult', {})
        balance = year_data.get('correction', {}).get('balance', {})

        profit = safe_convert(financial_result.get('current2400'))
        taxes = safe_convert(financial_result.get('current2410'))
        interest = safe_convert(financial_result.get('current2350'))
        depreciation = safe_convert(balance.get('current1150'))


        ebitda = profit + taxes + interest + depreciation
        ebitda_list.append({
            'year': year_data['period'],
            'ebitda': ebitda
        })

    return ebitda_list, None

results = []
total_inns = len(df)
checked_inns = 0

for index, row in df.iterrows():
    inn = row['ИНН']
    ebitda_data, error = calculate_ebitda(inn)

    checked_inns += 1

    if error:
        print(f"Ошибка для ИНН {inn}: {error}")
        continue

    for data in ebitda_data:
        results.append({
            'Наименование': row['Наименование / ФИО'],
            'ИНН': inn,
            'Год': data['year'],
            'EBITDA': data['ebitda']
        })

    if checked_inns % 1000 == 0:
        print(f"{checked_inns} ИНН проверено из {total_inns}.")

    time.sleep(1)
print(f"Все ИНН проверены. Всего проверено: {checked_inns}.")

ebitda_df = pd.DataFrame(results)
# Out:
# Ошибка для ИНН 6606022437: Организация не найдена
# Ошибка для ИНН 5009106346: Организация не найдена
# Ошибка для ИНН 7716988730: Организация не найдена
# Ошибка для ИНН 9729368920: Организация не найдена

# %%
results
