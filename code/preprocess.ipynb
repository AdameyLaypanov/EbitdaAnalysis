# %% [markdown]
# # **Создание нужной выборки ИНН-ов**

# %%
import pandas as pd
df = pd.read_excel('/Users/admlanno/Desktop/PetProjects/EbitdaAnalysis/data/Реестр.xlsx', skiprows=2)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.shape
# Out:
# (603520, 23)

# %%
df.sample(10)
# Out:
#          № п/п                                 Наименование / ФИО  \
# 445793  445794  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СТРО...
# 410979  410980  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СТРО...
# 513255  513256  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ ПСК "...
# 251934  251935  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМЛ...
# 316666  316667  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПИАР...
# 266366  266367  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЕМА...
# 241522  241523   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "К-ДСУ"
# 83128    83129                         КЛЮШИНА ОЛЬГА ВЛАДИМИРОВНА
# 291269  291270  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МОНТ...
# 537578  537579                         ПОЛЯНИН АЛЕКСЕЙ ВАСИЛЬЕВИЧ
#
#                           Тип субъекта                  Категория  \
# 445793                Юридическое лицо           Микропредприятие
# 410979                Юридическое лицо           Микропредприятие
# ...

# %%
df2 = df[
    (df['Тип субъекта'] == 'Юридическое лицо') &
    (df['Категория'].isin(['Малое предприятие', 'Среднее предприятие', 'Микропредприятие'])) &
    (df['Основной вид деятельности'].str.contains('41.20'))
]


df2.head()
# Out:
#     № п/п                                 Наименование / ФИО  \
# 3       4   "БАЗИС" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ
# 5       6   "БЕРЕГ" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ
# 6       7  "БРИГ-С" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ
# 8       9  "ВИРАЖ-2000" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕ...
# 13     14  "ДОКАСТР" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННО...
#
#         Тип субъекта         Категория           ОГРН         ИНН  \
# 3   Юридическое лицо  Микропредприятие  1025204411682  5263025484
# 5   Юридическое лицо  Микропредприятие  1035010950633  5056003490
# 6   Юридическое лицо  Микропредприятие  1022501801343  2537042746
# 8   Юридическое лицо  Микропредприятие  1022501797768  2537036693
# 13  Юридическое лицо  Микропредприятие  1032501797305  2537045144
#
#                      Основной вид деятельности                      Регион  \
# 3   41.20 Строительство жилых и нежилых зданий  52 - Нижегородская область
# ...

# %%
df2.shape
# Out:
# (142930, 23)

# %%
df2.to_csv('df_main.csv', index=False)
